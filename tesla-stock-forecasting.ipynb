# %%
# !pip install yfinance
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      -------------------------------------- - 2.9/3.0 MB 21.0 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 16.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for peewee: filename=peewee-3.17.9-py3-none-any.whl size=139127 sha256=b83711fd79569b2f65a846001d3d73d7d42f8ef86eba7c869690c462f3064eb9
#   Stored in directory: c:\users\fasee\appdata\local\pip\cache\wheels\fd\fd\5e\90b9ec95da4fd6c96237b580ce74f89d6bdea547ad151ab5f4
# ...

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
from pandas_datareader import data as pdr
import yfinance as yf
# yf.pdr_override()
y_symbols = ['TSLA']
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 3
#       1 from pandas_datareader import data as pdr
#       2 import yfinance as yf
# ----> 3 yf.pdr_override()
#       4 y_symbols = ['TSLA']
#       5 from datetime import datetime
#
# AttributeError: module 'yfinance' has no attribute 'pdr_override'

# %%
df_tesla = yf.Ticker("TSLA")
df_tesla = df_tesla.history(start = "2023-01-01", end= "2025-03-01")
df_tesla.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-01-03 00:00:00-05:00  118.470001  118.800003  104.639999  108.099998
# 2023-01-04 00:00:00-05:00  109.110001  114.589996  107.519997  113.639999
# 2023-01-05 00:00:00-05:00  110.510002  111.750000  107.160004  110.339996
# 2023-01-06 00:00:00-05:00  103.000000  114.389999  101.809998  113.059998
# 2023-01-09 00:00:00-05:00  118.959999  123.519997  117.110001  119.769997
#
#                               Volume  Dividends  Stock Splits
# Date
# 2023-01-03 00:00:00-05:00  231402800        0.0           0.0
# 2023-01-04 00:00:00-05:00  180389000        0.0           0.0
# 2023-01-05 00:00:00-05:00  157986300        0.0           0.0
# 2023-01-06 00:00:00-05:00  220911100        0.0           0.0
# 2023-01-09 00:00:00-05:00  190284000        0.0           0.0

# %%
df_tesla.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-02-24 00:00:00-05:00  338.140015  342.399994  324.700012  330.529999
# 2025-02-25 00:00:00-05:00  327.019989  328.890015  297.250000  302.799988
# 2025-02-26 00:00:00-05:00  303.709991  309.000000  288.040009  290.799988
# 2025-02-27 00:00:00-05:00  291.160004  297.230011  280.880005  281.950012
# 2025-02-28 00:00:00-05:00  279.500000  293.880005  273.600006  292.980011
#
#                               Volume  Dividends  Stock Splits
# Date
# 2025-02-24 00:00:00-05:00   76052300        0.0           0.0
# 2025-02-25 00:00:00-05:00  134228800        0.0           0.0
# 2025-02-26 00:00:00-05:00  100118300        0.0           0.0
# 2025-02-27 00:00:00-05:00  101748200        0.0           0.0
# 2025-02-28 00:00:00-05:00  115697000        0.0           0.0

# %%
df_tesla.shape
# Out:
# (541, 7)

# %%
df_tesla['High'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
## xlimit and y limit
df_tesla['High'].plot(xlim=['2024-11-01','2025-03-01'],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
## xlimit and y limit
df_tesla['High'].plot(xlim=['2024-11-01','2025-03-01'],ylim=[0,900],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
## xlimit and y limit and coloring
df_tesla['High'].plot(xlim=['2024-11-01','2025-03-01'],ylim=[0,900],figsize=(12,4),ls='--',c='green')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2023-01-03 00:00:00-05:00', '2023-01-04 00:00:00-05:00',
#                '2023-01-05 00:00:00-05:00', '2023-01-06 00:00:00-05:00',
#                '2023-01-09 00:00:00-05:00', '2023-01-10 00:00:00-05:00',
#                '2023-01-11 00:00:00-05:00', '2023-01-12 00:00:00-05:00',
#                '2023-01-13 00:00:00-05:00', '2023-01-17 00:00:00-05:00',
#                ...
#                '2025-02-14 00:00:00-05:00', '2025-02-18 00:00:00-05:00',
#                '2025-02-19 00:00:00-05:00', '2025-02-20 00:00:00-05:00',
#                '2025-02-21 00:00:00-05:00', '2025-02-24 00:00:00-05:00',
#                '2025-02-25 00:00:00-05:00', '2025-02-26 00:00:00-05:00',
#                '2025-02-27 00:00:00-05:00', '2025-02-28 00:00:00-05:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=541, freq=None)

# %%
index=df_tesla.loc['2024-11-01':'2025-03-01'].index
share_open=df_tesla.loc['2024-11-01':'2025-03-01']['Open']

# %%
share_open
# Out:
# Date
# 2024-11-01 00:00:00-04:00    252.039993
# 2024-11-04 00:00:00-05:00    244.559998
# 2024-11-05 00:00:00-05:00    247.339996
# 2024-11-06 00:00:00-05:00    284.670013
# 2024-11-07 00:00:00-05:00    288.890015
#                                 ...
# 2025-02-24 00:00:00-05:00    338.140015
# 2025-02-25 00:00:00-05:00    327.019989
# 2025-02-26 00:00:00-05:00    303.709991
# 2025-02-27 00:00:00-05:00    291.160004
# 2025-02-28 00:00:00-05:00    279.500000
# Name: Open, Length: 80, dtype: float64

# %%
index
# Out:
# DatetimeIndex(['2024-11-01 00:00:00-04:00', '2024-11-04 00:00:00-05:00',
#                '2024-11-05 00:00:00-05:00', '2024-11-06 00:00:00-05:00',
#                '2024-11-07 00:00:00-05:00', '2024-11-08 00:00:00-05:00',
#                '2024-11-11 00:00:00-05:00', '2024-11-12 00:00:00-05:00',
#                '2024-11-13 00:00:00-05:00', '2024-11-14 00:00:00-05:00',
#                '2024-11-15 00:00:00-05:00', '2024-11-18 00:00:00-05:00',
#                '2024-11-19 00:00:00-05:00', '2024-11-20 00:00:00-05:00',
#                '2024-11-21 00:00:00-05:00', '2024-11-22 00:00:00-05:00',
#                '2024-11-25 00:00:00-05:00', '2024-11-26 00:00:00-05:00',
#                '2024-11-27 00:00:00-05:00', '2024-11-29 00:00:00-05:00',
#                '2024-12-02 00:00:00-05:00', '2024-12-03 00:00:00-05:00',
#                '2024-12-04 00:00:00-05:00', '2024-12-05 00:00:00-05:00',
#                '2024-12-06 00:00:00-05:00', '2024-12-09 00:00:00-05:00',
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis=plt.subplots()
plt.tight_layout()
## Preventing overlapping
figure.autofmt_xdate()
axis.plot(index,share_open)

# %%
df_tesla=df_tesla.reset_index()

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          541 non-null    datetime64[ns, America/New_York]
#  1   Open          541 non-null    float64
#  2   High          541 non-null    float64
#  3   Low           541 non-null    float64
#  4   Close         541 non-null    float64
#  5   Volume        541 non-null    int64
#  6   Dividends     541 non-null    float64
#  7   Stock Splits  541 non-null    float64
# dtypes: datetime64[ns, America/New_York](1), float64(6), int64(1)
# memory usage: 33.9 KB

# %%
df_tesla=df_tesla.set_index('Date',drop=True)

# %%
df_tesla.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-01-03 00:00:00-05:00  118.470001  118.800003  104.639999  108.099998
# 2023-01-04 00:00:00-05:00  109.110001  114.589996  107.519997  113.639999
# 2023-01-05 00:00:00-05:00  110.510002  111.750000  107.160004  110.339996
# 2023-01-06 00:00:00-05:00  103.000000  114.389999  101.809998  113.059998
# 2023-01-09 00:00:00-05:00  118.959999  123.519997  117.110001  119.769997
#
#                               Volume  Dividends  Stock Splits
# Date
# 2023-01-03 00:00:00-05:00  231402800        0.0           0.0
# 2023-01-04 00:00:00-05:00  180389000        0.0           0.0
# 2023-01-05 00:00:00-05:00  157986300        0.0           0.0
# 2023-01-06 00:00:00-05:00  220911100        0.0           0.0
# 2023-01-09 00:00:00-05:00  190284000        0.0           0.0
